# %%
import geopandas as gpd
import pandas as pd
import json

# %%
pd.set_option('display.max_rows', None)     # Print every single row

# %%
kotaadm = "data/geoBoundaries-IDN-ADM2_simplified.shp"
jaksel_adm = "data/KOTA_JAKARTA_SELATAN/ADMINISTRASIDESA_AR_25K.shp"
jakbar_adm = "data/KOTA_JAKARTA_BARAT/ADMINISTRASIDESA_AR_25K.shp"
jakpus_adm = "data/KOTA_JAKARTA_PUSAT/ADMINISTRASIDESA_AR_25K.shp"
jaktim_adm = "data/KOTA_JAKARTA_TIMUR/ADMINISTRASIDESA_AR_25K.shp"
jakut_adm = "data/KOTA_JAKARTA_UTARA/ADMINISTRASIDESA_AR_25K.shp"

# %%
data_jaktim = gpd.read_file(jaktim_adm)
data_jakut = gpd.read_file(jakut_adm)
data_jaksel = gpd.read_file(jaksel_adm)

data_jaktim.to_crs(EPSG)
#data_jaktim.sjoin(data_jaksel).plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 5
#       1 data_jaktim = gpd.read_file(jaktim_adm)
#       2 data_jakut = gpd.read_file(jakut_adm)
#       3 data_jaksel = gpd.read_file(jaksel_adm)
#       4
# ----> 5 data_jaktim.to_crs()
#       6 #data_jaktim.sjoin(data_jaksel).plot()
#
# File ~/miniconda3/envs/geoai/lib/python3.11/site-packages/geopandas/geodataframe.py:1842, in GeoDataFrame.to_crs(self, crs, epsg, inplace)
#    1840 else:
#    1841     df = self.copy(deep=not PANDAS_GE_30)
# -> 1842 geom = df.geometry.to_crs(crs=crs, epsg=epsg)
#    1843 df.geometry = geom
#    1844 if not inplace:
#
# File ~/miniconda3/envs/geoai/lib/python3.11/site-packages/geopandas/geoseries.py:1251, in GeoSeries.to_crs(self, crs, epsg)
#    1174 def to_crs(self, crs: Any | None = None, epsg: int | None = None) -> GeoSeries:
#    1175     """Return a ``GeoSeries`` with all geometries transformed to a new
#    1176     coordinate reference system.
#    1177
#    (...)   1248
#    1249     """
#    1250     return GeoSeries(
# -> 1251         self.values.to_crs(crs=crs, epsg=epsg), index=self.index, name=self.name
#    1252     )
#
# File ~/miniconda3/envs/geoai/lib/python3.11/site-packages/geopandas/_compat.py:88, in requires_pyproj.<locals>.wrapper(*args, **kwargs)
#      82 if not HAS_PYPROJ:
#      83     raise ImportError(
#      84         f"The 'pyproj' package is required for {func.__name__} to work. "
#      85         "Install it and initialize the object with a CRS before using it."
#      86         f"\nImporting pyproj resulted in: {pyproj_import_error}"
#      87     )
# ---> 88 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/geoai/lib/python3.11/site-packages/geopandas/array.py:1123, in GeometryArray.to_crs(self, crs, epsg)
#    1121     crs = CRS.from_epsg(epsg)
#    1122 else:
# -> 1123     raise ValueError("Must pass either crs or epsg.")
#    1125 # skip if the input CRS and output CRS are the exact same
#    1126 if self.crs.is_exact_same(crs):
#
# ValueError: Must pass either crs or epsg.

# %%
df = gpd.read_file(kotaadm)
jakarta = ["Kota Jakarta Barat", "Kota Jakarta Timur", "Kota Jakarta Pusat", "Kota Jakarta Utara", "Kota Jakarta Selatan"
           #, "Kepulauan Seribu"
          ]
df[df["shapeName"].isin(jakarta)].plot()
# Out:
# <Axes: >

# %%
df.query("shapeName" == "Jakarta Barat")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 df.query("shapeName" == "Jakarta Barat")
#
# File ~/miniconda3/envs/geoai/lib/python3.11/site-packages/pandas/core/frame.py:5191, in DataFrame.query(self, expr, parser, engine, local_dict, global_dict, resolvers, level, inplace)
#    5187         """
#    5188         inplace = validate_bool_kwarg(inplace, "inplace")
#    5189         if not isinstance(expr, str):
#    5190             msg = f"expr must be a string to be evaluated, {type(expr)} given"
# -> 5191             raise ValueError(msg)
#    5192
#    5193         res = self.eval(
#    5194             expr,
#
# ValueError: expr must be a string to be evaluated, <class 'bool'> given

# %%
import geopandas as gpd
import pandas as pd

# %%
kelurahan = "data/geoBoundaries-IDN-ADM2-simplified.shp"
kecamatan = "data/geoBoundaries-IDN-ADM1-simplified.shp"

# %%
df = gpd.read_file(kelurahan)
jakarta = ["Kota Jakarta Barat", "Kota Jakarta Timur", "Kota Jakarta Pusat", "Kota Jakarta Utara", "Kota Jakarta Selatan", "Kepulauan Seribu"]
df[df["shapeName"].isin(jakarta)]

# %%
pd.set_option('display.max_rows', None)     # Print every single row
